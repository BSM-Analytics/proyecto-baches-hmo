# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import requests
import os
import zipfile

# %%
url = 'https://www.coneval.org.mx/Medicion/Documents/Pobreza_urbana/Base_de_datos/Base_de_datos_de_pobreza_AGEB_segun_entidad_federativa_2015.zip'
directorio = os.path.dirname(os.getcwd())

# %%
if not os.path.exists(directorio + '/data/raw/pobreza_ageb.zip'):
    if not os.path.exists(directorio + '/data/raw'):
        if not os.path.exists(directorio + '/data'):
            os.makedirs(directorio + '/data')
        os.makedirs(directorio + '/data/raw')
    r = requests.get(url, allow_redirects=True) 
    open(directorio + '/data/raw/pobreza_ageb.zip', 'wb').write(r.content)

if os.path.exists(directorio + '/data/raw/pobreza_ageb.zip'):
    with zipfile.ZipFile(directorio + '/data/raw/pobreza_ageb.zip') as f:
        f.extractall(path=directorio + '/data/raw')
    os.remove(directorio + '/data/raw/pobreza_ageb.zip')

# %% [markdown]
# hermosillo.rezago10_loc.unique()

# %%
hermosillo = pd.read_excel(directorio + '/data/raw//Base de datos de pobreza AGEB segun entidad federativa 2015.xlsx', sheet_name='Sonora', header=4)
hermosillo = hermosillo.drop(columns=['Unnamed: 0'])
hermosillo = hermosillo.drop([0, 1]).reset_index(drop=True)
hermosillo.head()
# Out:
#   Clave de entidad Entidad \nfederativa  Clave de municipio    Municipio  \
# 0               26               Sonora             26002.0  Agua Prieta
# 1               26               Sonora             26002.0  Agua Prieta
# 2               26               Sonora             26002.0  Agua Prieta
# 3               26               Sonora             26002.0  Agua Prieta
# 4               26               Sonora             26002.0  Agua Prieta
#
#   Clave de \nAGEB              Rango de pobreza (%)  \
# 0   2600200010512                          (34, 50]
# 1   2600200010527  Una vivienda particular habitada
# 2   2600200010531                          (18, 34]
# 3   2600200010546                          (18, 34]
# 4   2600200010550                          (18, 34]
#
#        Rango de pobreza extrema (%)
# 0                          [ 0, 20]
# 1  Una vivienda particular habitada
# 2                          [ 0, 20]
# 3                          [ 0, 20]
# ...

# %%
lista = ['2603000011869',
 '2603000011746',
 '2603000012246',
 '2603000011750',
 '2603000011799',
 '260300001177A',
 '260300001191A',
 '260300001184A',
 '260300001202A',
 '2603000012532',
 '2603000012547',
 '2603000012566',
 '2603000012570',
 '2603000012551',
 '2603000011835',
 '2603000011854',
 '2603000011873',
 '2603000011888',
 '2603000011905',
 '2603000011924',
 '2603000011939',
 '2603000011943',
 '2603000011958',
 '2603000011996',
 '2603000012000',
 '2603000012015',
 '2603000012049',
 '2603000012068',
 '2603000012072',
 '2603000012208',
 '2603000012250',
 '2603000012265',
 '2603000012299',
 '2603000012354',
 '2603000012335',
 '2603000012373',
 '2603000012388',
 '2603000012405',
 '2603000012443',
 '2603000012458',
 '2603000012509',
 '2603000012513',
 '2603000012528',
 '2603000012481',
 '260300001234A',
 '2603000012087',
 '2603000015132',
 '2603000015151',
 '2603000015166',
 '2603000015170',
 '2603000015185',
 '2603000015202',
 '2603000015221',
 '2603000015236',
 '2603000015240',
 '2603000015255',
 '2603000013390',
 '2603000013418',
 '2603000013422',
 '2603000013437',
 '2603000017919',
 '2603000017938',
 '2603000017942',
 '2603000017957',
 '2603000017961',
 '2603000017976',
 '2603000017980',
 '2603000017995',
 '260300001800A',
 '2603000018029',
 '2603000018052',
 '2603000018067',
 '2603000018071',
 '2603000018090',
 '2603000018103',
 '2603000018118',
 '2603000018122',
 '2603000016431',
 '2603000018048',
 '2603000018353',
 '2603000018368',
 '2603000018372',
 '2603000018404',
 '2603000018419',
 '2603000018461',
 '2603000018476',
 '2603000018480',
 '2603000018495',
 '2603000018508',
 '2603000018512',
 '2603000018527',
 '2603000018531',
 '2603000018546',
 '2603000018601',
 '2603000018616',
 '2603000018620',
 '2603000018635',
 '260300001864A',
 '2603000018654',
 '2603000018669',
 '2603000018673',
 '2603000018688',
 '2603000018758',
 '2603000018743',
 '2603000018739',
 '2603000018724',
 '260300001871A',
 '2603000018692',
 '2603000018457',
 '2603000017410',
 '2603000017406',
 '2603000018550',
 '2603000018705',
 '2603000017622',
 '2603000018885',
 '2603000018989',
 '2603000018974',
 '260300001896A',
 '2603000018902',
 '260300001889A',
 '2603000018993',
 '2603000018955',
 '2603000017923',
 '2603000018940',
 '2603000018917',
 '2603000018921',
 '2603000018936',
 '2603000018866',
 '2603000018870',
 '2603000010023']

# %%
hermosillo = hermosillo[hermosillo['Municipio'] == 'Hermosillo']
hermosillo = hermosillo[hermosillo['Clave de \nAGEB'].isin(lista)]
hermosillo = hermosillo.reset_index(drop=True)
hermosillo.head()
# Out:
#   Clave de entidad Entidad \nfederativa  Clave de municipio   Municipio  \
# 0               26               Sonora             26030.0  Hermosillo
# 1               26               Sonora             26030.0  Hermosillo
# 2               26               Sonora             26030.0  Hermosillo
# 3               26               Sonora             26030.0  Hermosillo
# 4               26               Sonora             26030.0  Hermosillo
#
#   Clave de \nAGEB                  Rango de pobreza (%)  \
# 0   2603000010023  Sin viviendas particulares habitadas
# 1   2603000011746                              (18, 34]
# 2   2603000011750                              [ 0, 18]
# 3   260300001177A                              [ 0, 18]
# 4   2603000011799                              (18, 34]
#
#            Rango de pobreza extrema (%)
# 0  Sin viviendas particulares habitadas
# 1                              [ 0, 20]
# 2                              [ 0, 20]
# ...

# %%
df = gpd.read_file(directorio + '/data/raw/260300001a.shp')

# %%
hmo1 = df.merge(hermosillo[['Clave de \nAGEB','Rango de pobreza (%)','Rango de pobreza extrema (%)']], left_on='CVEGEO', right_on='Clave de \nAGEB')

# %%
hmo1
# Out:
#                      GEOGRAFICO         CVEGEO  CODIGO FECHAACT INSTITUC  \
# 0    ÁREA GEOESTADÍSTICA BÁSICA  2603000011869    6052  12/2007    INEGI
# 1    ÁREA GEOESTADÍSTICA BÁSICA  2603000011746    6052  12/2007    INEGI
# 2    ÁREA GEOESTADÍSTICA BÁSICA  2603000012246    6052  12/2007    INEGI
# 3    ÁREA GEOESTADÍSTICA BÁSICA  2603000011750    6052  12/2007    INEGI
# 4    ÁREA GEOESTADÍSTICA BÁSICA  2603000011799    6052  12/2007    INEGI
# ..                          ...            ...     ...      ...      ...
# 457  ÁREA GEOESTADÍSTICA BÁSICA  2603000018921    6052  12/2007    INEGI
# 458  ÁREA GEOESTADÍSTICA BÁSICA  2603000018936    6052  12/2007    INEGI
# 459  ÁREA GEOESTADÍSTICA BÁSICA  2603000018866    6052  12/2007    INEGI
# 460  ÁREA GEOESTADÍSTICA BÁSICA  2603000018870    6052  12/2007    INEGI
# 461  ÁREA GEOESTADÍSTICA BÁSICA  2603000010023    6052  12/2007    INEGI
#
#     GEOMETRIA                                           geometry  \
# ...

# %%
# Plot with different colors for each category
fig, ax = plt.subplots(figsize=(10, 8))
hmo1.plot(column='Rango de pobreza (%)', cmap='YlOrBr', legend=True, ax=ax)

# Customize plot labels and title
ax.set_title("Hermosillo Pobreza")

plt.show()

# %%
url = 'https://datos.sonora.gob.mx/dataset/5e793058-f3bd-4dbb-b250-401e1f54a13e/resource/ab445a80-55b5-40b2-837a-09174be9391b/download/indice-de-marginacion-ageb-2020.xlsx'

if not os.path.exists(directorio + '/data/raw/pobreza_ageb_2020.xlsx'):
    if not os.path.exists(directorio + '/data/raw'):
        if not os.path.exists(directorio + '/data'):
            os.makedirs(directorio + '/data')
        os.makedirs(directorio + '/data/raw')
    r = requests.get(url, allow_redirects=True) 
    open(directorio + '/data/raw/pobreza_ageb_2020.xlsx', 'wb').write(r.content)

# %%
ageb_hmo = pd.read_excel(directorio + '/data/raw/pobreza_ageb_2020.xlsx')
ageb_hmo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2096 entries, 0 to 2095
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CVE_AGEB  2096 non-null   object
#  1   ENT       2096 non-null   int64
#  2   NOM_ENT   2096 non-null   object
#  3   MUN       2096 non-null   int64
#  4   NOM_MUN   2096 non-null   object
#  5   LOC       2096 non-null   int64
#  6   NOM_LOC   2096 non-null   object
#  7   AGEB      2096 non-null   object
#  8   POB_TOT   2096 non-null   int64
#  9   P6A14NAE  2096 non-null   float64
#  10  SBASC     2096 non-null   float64
#  11  PSDSS     2096 non-null   float64
#  12  OVSDE     2096 non-null   float64
#  13  OVSEE     2096 non-null   float64
#  14  OVSAE     2096 non-null   float64
#  15  OVPT      2096 non-null   float64
#  16  OVHAC     2096 non-null   float64
#  17  OVSREF    2096 non-null   float64
#  18  OVSINT    2096 non-null   float64
#  19  OSCEL     2096 non-null   float64
# ...

# %%
ageb_hmo.head()
# Out:
#         CVE_AGEB  ENT NOM_ENT  MUN      NOM_MUN  LOC      NOM_LOC  AGEB  \
# 0  2600100010055   26  Sonora    1      Aconchi    1      Aconchi  0055
# 1  260010001006A   26  Sonora    1      Aconchi    1      Aconchi  006A
# 2  2600100010110   26  Sonora    1      Aconchi    1      Aconchi  0110
# 3  260010001013A   26  Sonora    1      Aconchi    1      Aconchi  013A
# 4  2600200010512   26  Sonora    2  Agua Prieta    1  Agua Prieta  0512
#
#    POB_TOT  P6A14NAE  ...     OVSEE     OVSAE      OVPT      OVHAC    OVSREF  \
# 0      764  2.857143  ...  0.130890  0.000000  0.000000  25.261780  2.748691
# 1      658  6.024096  ...  0.151976  0.000000  0.000000  14.133739  3.191489
# 2       82  0.000000  ...  0.000000  1.219512  0.000000  56.097561  0.000000
# 3       72  0.000000  ...  0.000000  0.000000  0.000000  72.222222  8.333333
# 4     1176  2.366864  ...  0.683177  0.000000  0.170794  24.594364  3.757472
#
#       OVSINT     OSCEL     IM_2020  GM_2020  IMN_2020
# ...

# %%
df.CVEGEO = df.CVEGEO.str[-4:]
df
# Out:
#                      GEOGRAFICO CVEGEO  CODIGO FECHAACT INSTITUC GEOMETRIA  \
# 0    ÁREA GEOESTADÍSTICA BÁSICA   1869    6052  12/2007    INEGI      ÁREA
# 1    ÁREA GEOESTADÍSTICA BÁSICA   1746    6052  12/2007    INEGI      ÁREA
# 2    ÁREA GEOESTADÍSTICA BÁSICA   2246    6052  12/2007    INEGI      ÁREA
# 3    ÁREA GEOESTADÍSTICA BÁSICA   1750    6052  12/2007    INEGI      ÁREA
# 4    ÁREA GEOESTADÍSTICA BÁSICA   1799    6052  12/2007    INEGI      ÁREA
# ..                          ...    ...     ...      ...      ...       ...
# 459  ÁREA GEOESTADÍSTICA BÁSICA   8921    6052  12/2007    INEGI      ÁREA
# 460  ÁREA GEOESTADÍSTICA BÁSICA   8936    6052  12/2007    INEGI      ÁREA
# 461  ÁREA GEOESTADÍSTICA BÁSICA   8866    6052  12/2007    INEGI      ÁREA
# 462  ÁREA GEOESTADÍSTICA BÁSICA   8870    6052  12/2007    INEGI      ÁREA
# 463  ÁREA GEOESTADÍSTICA BÁSICA   0023    6052  12/2007    INEGI      ÁREA
#
#                                               geometry
# ...

# %%
ageb = df.merge(ageb_hmo, left_on='CVEGEO', right_on='AGEB')
ageb.head()
# Out:
#                    GEOGRAFICO CVEGEO  CODIGO FECHAACT INSTITUC GEOMETRIA  \
# 0  ÁREA GEOESTADÍSTICA BÁSICA   1869    6052  12/2007    INEGI      ÁREA
# 1  ÁREA GEOESTADÍSTICA BÁSICA   1746    6052  12/2007    INEGI      ÁREA
# 2  ÁREA GEOESTADÍSTICA BÁSICA   2246    6052  12/2007    INEGI      ÁREA
# 3  ÁREA GEOESTADÍSTICA BÁSICA   1750    6052  12/2007    INEGI      ÁREA
# 4  ÁREA GEOESTADÍSTICA BÁSICA   1799    6052  12/2007    INEGI      ÁREA
#
#                                             geometry       CVE_AGEB  ENT  \
# 0  POLYGON ((1628105.477 1920205.715, 1628295.245...  2603000011869   26
# 1  POLYGON ((1628032.93 1921100.78, 1628030.077 1...  2603000011746   26
# 2  POLYGON ((1623070.211 1922088.608, 1623066.931...  2603000012246   26
# 3  POLYGON ((1628614.97 1922405.429, 1628619.025 ...  2603000011750   26
# 4  POLYGON ((1626439.624 1919837.824, 1626436.398...  2603000011799   26
#
#   NOM_ENT  ...     OVSEE     OVSAE      OVPT      OVHAC    OVSREF     OVSINT  \
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 8))
ageb.plot(column='GM_2020', cmap='YlOrBr', legend=True, ax=ax)

# Customize plot labels and title
ax.set_title("Hermosillo Pobreza")

plt.show()
